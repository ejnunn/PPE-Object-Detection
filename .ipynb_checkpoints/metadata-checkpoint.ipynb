# %%
import pandas as pd
import os
import numpy as np

# %%
# File name for the metadata to use in app.py
METADATA_FILE = 'labels.csv'
# ordering of columns in BOTH this file and app.py
COLUMN_ORDER = ['label', 'xmin', 'xmax', 'ymin', 'ymax', 'image']

# %%
# list of image names
image_files = os.listdir('ppe_data/images')
label_files = os.listdir('ppe_data/labels')

# %%
# Add one row for each label
# For each image
temp = []
for file in label_files:
    image_file = file[:-3] + 'jpg'
    try:
        with open('ppe_data/labels/' + file, encoding='utf-8') as f:
            for line in f.readlines():
                temp.append([item for item in line.strip('\n').split(' ')] + [image_file])
    except:
        continue
metadata = pd.DataFrame(temp, columns=COLUMN_ORDER)
print('metadata created')
# Out:
# line:  2 34 201 -290 22
#
# line:  2 328 492 -308 12
#
# line:  1 13 694 -667 120
#
# line:  1 495 840 -685 112
#
# line:  1 677 1013 -695 110
#
# line:  2 543 697 -424 112
#
# line:  1 569 690 -23 175
#
# line:  0 579 658 43 119
#
# line:  0 183 1367 -638 183
#
# line:  2 0 192 -410 45
#
# line:  0 32 130 -20 43
#
# line:  2 38 132 22 146
#
# line:  2 142 217 13 142
#
# line:  2 223 292 25 150
#
# line:  2 295 361 16 144
#
# line:  2 346 394 -148 57
#
# line:  2 307 338 21 81
#
# line:  2 240 298 9 78
#
# line:  2 193 239 18 81
#
# line:  2 140 187 -4 69
#
# line:  2 87 132 11 77
#
# line:  2 307 402 -109 97
#
# line:  2 179 340 -156 80
#
# line:  2 134 230 -128 83
#
# line:  2 0 986 -720 0
#
# line:  1 0 567 180 450
#
# line:  2 99 195 -257 59
#
# line:  2 220 334 -258 58
#
# line:  2 273 500 -329 23
#
# line:  0 131 181 35 62
#
# line:  0 221 251 51 71
#
# line:  0 263 316 15 56
#
# line:  0 349 475 -46 22
#
# line:  2 51 225 -437 31
#
# line:  0 109 222 -62 28
#
# ...

# %%
metadata
# Out:
#      label xmin  xmax  ymin ymax         image
# 0        2   34   201  -290   22  neg_1303.jpg
# 1        2  328   492  -308   12  neg_1303.jpg
# 2        1   13   694  -667  120   pos_181.jpg
# 3        1  495   840  -685  112   pos_181.jpg
# 4        1  677  1013  -695  110   pos_181.jpg
# ...    ...  ...   ...   ...  ...           ...
# 1453     0  464   596   -47   42  pos_1810.jpg
# 1454     2   64   402  -480    0   pos_629.jpg
# 1455     1  117   350  -259   55   pos_629.jpg
# 1456     2    2   370  -436   32   neg_819.jpg
# 1457     2  243   408  -222  139   neg_819.jpg
#
# [1458 rows x 6 columns]

# %%
# Convert integer category label to object name string
metadata.loc[metadata['label'] == '0', 'label'] = 'safetyVest'
metadata.loc[metadata['label'] == '1', 'label'] = 'hardHat'
metadata.loc[metadata['label'] == '2', 'label'] = 'person'

# %%
# Convert string coordinates to float coordinates
metadata['xmin'] = metadata['ymin'].astype(float)
metadata['xmax'] = metadata['xmax'].astype(float)
metadata['ymin'] = metadata['ymin'].astype(float)
metadata['ymax'] = metadata['ymax'].astype(float)

# %%
metadata.describe()
# Out:
#               xmin         xmax         ymin         ymax
# count  6203.000000  6203.000000  6203.000000  6203.000000
# mean    -81.787367   324.291693   -81.787367    95.080991
# std     210.092222   355.482694   210.092222   113.001817
# min   -1682.000000     0.006466 -1682.000000     0.000000
# 25%    -152.500000     0.694667  -152.500000     0.716366
# 50%       0.070140   257.000000     0.070140    64.000000
# 75%       0.766406   463.000000     0.766406   154.500000
# max     608.000000  3596.000000   608.000000  1092.000000

# %%
# Convert string coordinates to float coordinates
metadata['xmin'] = metadata['ymin'].astype(int)
metadata['xmax'] = metadata['xmax'].astype(int)
metadata['ymin'] = metadata['ymin'].astype(int)
metadata['ymax'] = metadata['ymax'].astype(int)

# %%
# Save file
metadata.to_csv(METADATA_FILE, index=False)
