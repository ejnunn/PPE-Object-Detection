# %%
import pandas as pd
import os
import numpy as np
import cv2

# %%
# File name for the metadata to use in app.py
DATASET = 'train_data/'
METADATA_FILE = DATASET + 'labels.csv'
# ordering of columns in BOTH this file and app.py
YOLO_ORDER = ['label', 'x', 'y', 'w', 'h', 'image']
APP_ORDER = ['label', 'xmin', 'ymin', 'xmax', 'ymax', 'image']

# %%
# list of image names
image_files = [x for x in os.listdir(DATASET + 'obj/') if x[-4:] == '.jpg']
label_files = [x for x in os.listdir(DATASET + 'obj/') if x[-4:] == '.txt']
print(image_files)
# Out:
# ['neg_282.jpg', 'neg_296.jpg', 'pos_518.jpg', 'pos_256.jpg', 'pos_530.jpg', 'pos_524.jpg', 'pos_242.jpg', 'pos_2033.jpg', 'neg_527.jpg', 'neg_241.jpg', 'neg_255.jpg', 'pos_1248.jpg', 'neg_533.jpg', 'pos_2027.jpg', 'pos_1506.jpg', 'pos_295.jpg', 'neg_1017.jpg', 'pos_1260.jpg', 'pos_1274.jpg', 'neg_269.jpg', 'neg_1003.jpg', 'pos_281.jpg', 'pos_1512.jpg', 'pos_1923.jpg', 'pos_1937.jpg', 'pos_1089.jpg', 'pos_732.jpg', 'neg_902.jpg', 'neg_916.jpg', 'pos_726.jpg', 'pos_915.jpg', 'neg_1229.jpg', 'pos_1738.jpg', 'neg_725.jpg', 'neg_731.jpg', 'pos_901.jpg', 'pos_1062.jpg', 'pos_929.jpg', 'neg_1215.jpg', 'neg_719.jpg', 'pos_1704.jpg', 'pos_1710.jpg', 'neg_1201.jpg', 'pos_1076.jpg', 'pos_15.jpg', 'neg_692.jpg', 'pos_1857.jpg', 'neg_686.jpg', 'pos_1843.jpg', 'pos_108.jpg', 'neg_98.jpg', 'pos_646.jpg', 'neg_876.jpg', 'pos_120.jpg', 'pos_29.jpg', 'pos_134.jpg', 'neg_862.jpg', 'pos_652.jpg', 'pos_861.jpg', 'neg_137.jpg', 'pos_1894.jpg', 'neg_889.jpg', 'neg_651.jpg', 'pos_1880.jpg', 'pos_1658.jpg', 'neg_645.jpg', 'neg_123.jpg', 'neg_1349.jpg', 'pos_875.jpg', 'pos_1116.jpg', 'neg_73.jpg', 'pos_685.jpg', 'pos_1670.jpg', 'neg_679.jpg', 'pos_1664.jpg', 'pos_691.jpg', 'pos_849.jpg', 'pos_1102.jpg', 'neg_67.jpg', 'neg_490.jpg', 'pos_2184.jpg', 'pos_478.jpg', 'neg_1188.jpg', 'neg_484.jpg', 'pos_1499.jpg', 'pos_322.jpg', 'pos_444.jpg', 'pos_450.jpg', 'pos_336.jpg', 'pos_2147.jpg', 'neg_453.jpg', 'neg_335.jpg', 'pos_1328.jpg', 'neg_321.jpg', 'neg_447.jpg', 'pos_2153.jpg', 'pos_1472.jpg', 'pos_487.jpg', 'neg_1163.jpg', 'pos_1314.jpg', 'neg_309.jpg', 'pos_1300.jpg', 'pos_493.jpg', 'neg_1177.jpg', 'pos_1466.jpg', 'neg_1176.jpg', 'pos_492.jpg', 'pos_1301.j
pos_725.jpg', 'pos_1908.jpg', 'neg_915.jpg', 'neg_901.jpg', 'pos_731.jpg', 'pos_1049.jpg', 'pos_902.jpg', 'neg_732.jpg', 'neg_726.jpg', 'pos_916.jpg', 'neg_1202.jpg', 'pos_1075.jpg', 'pos_1713.jpg', 'pos_1707.jpg', 'pos_1061.jpg', 'neg_1216.jpg', 'neg_685.jpg', 'pos_1698.jpg', 'pos_1840.jpg', 'pos_16.jpg', 'n ...

# %%
# Rename files to match all image/label name formats
for i in range(len(image_files)):
    old_image_file = DATASET + 'obj/' + image_files[i][:-4] + '.jpg'
    new_image_file = DATASET + 'obj/' + 'frame-' + str(i).zfill(3) + '.jpg'
    try:
        os.rename(old_image_file, new_image_file)
    except:
        continue
        
for i in range(len(label_files)):
    old_text_file = DATASET + 'obj/' + label_files[i][:-4] + '.txt'
    new_text_file = DATASET + 'obj/' + 'frame-' + str(i).zfill(3) + '.txt'
    try:
        os.rename(old_text_file, new_text_file)
    except:
        continue
        
# update local variable to keep up with file names
image_files = [x for x in os.listdir(DATASET + 'obj/') if x[-4:] == '.jpg']
label_files = [x for x in os.listdir(DATASET + 'obj/') if x[-4:] == '.txt']
print(label_files)

# %%
# Add one row for each label
# For each image
temp = []
for file in label_files:
    try:
        image_file =  file[:-4] + '.jpg'
        with open(DATASET + 'obj/' + file, encoding='utf-8') as f:
            for line in f.readlines():
                temp.append([item for item in line.strip('\n').split(' ')] + [image_file])
    except:
        continue
metadata = pd.DataFrame(temp, columns=YOLO_ORDER)
print('metadata created')

# %%
image_file = metadata.loc[0]['image']
image = cv2.imread(DATASET + 'obj/' + image_file)
print(image)

# %%
# Convert integer category label to object name string
metadata.loc[metadata['label'] == '0', 'label'] = 'Hard Hat'
metadata.loc[metadata['label'] == '1', 'label'] = 'Safety Vest'

# %%
# Convert string coordinates to float coordinates
metadata['x'] = metadata['x'].astype(float)
metadata['y'] = metadata['y'].astype(float)
metadata['w'] = metadata['w'].astype(float)
metadata['h'] = metadata['h'].astype(float)

# %%
for image_file in image_files:
    image = cv2.imread(DATASET + 'obj/' + image_file)
    h, w = image.shape[:2]
    metadata.loc[metadata['image'] == image_file, ['x', 'w']] *= w
    metadata.loc[metadata['image'] == image_file, ['y', 'h']] *= h

# %%
metadata

# %%
metadata['xmin'] = metadata['x'] - metadata['w']/2
metadata['ymin'] = metadata['y'] - metadata['h']/2
metadata['xmax'] = metadata['x'] + metadata['w']/2
metadata['ymax'] = metadata['y'] + metadata['h']/2

# %%
# Convert float coordinates to int coordinates
metadata['xmin'] = metadata['xmin'].astype(int)
metadata['ymin'] = metadata['ymin'].astype(int)
metadata['xmax'] = metadata['xmax'].astype(int)
metadata['ymax'] = metadata['ymax'].astype(int)

# %%
# Drop unused columns
metadata = metadata[APP_ORDER]

# %%
# Check that coordinates fit within image size
metadata[metadata['image'] == 'pos_1003.jpg']

# %%
# Stop "Run All" execution before saving file
assert False

# %%
# Save file
metadata.to_csv(METADATA_FILE, index=False)
