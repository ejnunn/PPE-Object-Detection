# %%
import pandas as pd
import os
import numpy as np

# %%
# list of image names
image_files = os.listdir('ppe_data/images')

# %%
label_files = os.listdir('ppe_data/labels')

# %%
# Add one row for each label
# For each image
temp = []
for file in label_files:
    with open('ppe_data/labels/' + file, 'r') as f:
        for line in f.readlines():
            temp.append([item for item in line.strip('\n').split(' ')] + [file])
metadata = pd.DataFrame(temp, columns=['label', 'xmin', 'ymin', 'xmax', 'ymin', 'image'])

# %%
metadata
# Out:
#      label                 xmin                 ymin                 xmax  \
# 0        2                 0.82   0.5149700598802395                0.328
# 1        2                0.235   0.5329341317365269                0.334
# 2        2                 0.82   0.5149700598802395                0.328
# 3        1         0.8251953125        0.50048828125             0.328125
# 4        1        0.34521484375        0.50146484375         0.6650390625
# ...    ...                  ...                  ...                  ...
# 1824     2  0.48541666666666666                  0.5   0.7041666666666667
# 1825     1   0.4864583333333333  0.44166666666666665  0.48541666666666666
# 1826     2   0.7977941176470589                0.639  0.40441176470588236
# 1827     2  0.45588235294117646                0.532   0.9019607843137255
# 1828     2   0.7977941176470589                0.639  0.40441176470588236
#
#                     ymin         image
# 0     0.9580838323353293  neg_1303.txt
# ...

# %%
metadata.loc[metadata['label'] == '0', 'label'] = 'safetyVest'
metadata.loc[metadata['label'] == '1', 'label'] = 'hardHat'
metadata.loc[metadata['label'] == '2', 'label'] = 'person'

# %%
metadata
# Out:
#         label                 xmin                 ymin                 xmax  \
# 0      person                 0.82   0.5149700598802395                0.328
# 1      person                0.235   0.5329341317365269                0.334
# 2      person                 0.82   0.5149700598802395                0.328
# 3     hardHat         0.8251953125        0.50048828125             0.328125
# 4     hardHat        0.34521484375        0.50146484375         0.6650390625
# ...       ...                  ...                  ...                  ...
# 1824   person  0.48541666666666666                  0.5   0.7041666666666667
# 1825  hardHat   0.4864583333333333  0.44166666666666665  0.48541666666666666
# 1826   person   0.7977941176470589                0.639  0.40441176470588236
# 1827   person  0.45588235294117646                0.532   0.9019607843137255
# 1828   person   0.7977941176470589                0.639  0.40441176470588236
#
#                     ymin         image
# ...

# %%
METADATA_FILE = 'labels.csv'
#metadata = pd.read_csv(METADATA_FILE)

# %%
metadata.rename(columns={'ymin2':'ymax'}, inplace=True)

# %%
metadata.to_csv(METADATA_FILE, index=False)

# %%
metadata
# Out:
#         label                 xmin                 ymin                 xmax  \
# 0      person                 0.82   0.5149700598802395                0.328
# 1      person                0.235   0.5329341317365269                0.334
# 2      person                 0.82   0.5149700598802395                0.328
# 3     hardHat         0.8251953125        0.50048828125             0.328125
# 4     hardHat        0.34521484375        0.50146484375         0.6650390625
# ...       ...                  ...                  ...                  ...
# 1824   person  0.48541666666666666                  0.5   0.7041666666666667
# 1825  hardHat   0.4864583333333333  0.44166666666666665  0.48541666666666666
# 1826   person   0.7977941176470589                0.639  0.40441176470588236
# 1827   person  0.45588235294117646                0.532   0.9019607843137255
# 1828   person   0.7977941176470589                0.639  0.40441176470588236
#
#                     ymin         image
# ...
